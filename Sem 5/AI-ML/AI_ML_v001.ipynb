# %% [markdown]
# **CSV**

# %%
import pandas as pd
data = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
data
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 0        -114.31     34.19  ...         1.4936             66900.0
# 1        -114.47     34.40  ...         1.8200             80100.0
# 2        -114.56     33.69  ...         1.6509             85700.0
# 3        -114.57     33.64  ...         3.1917             73400.0
# 4        -114.57     33.57  ...         1.9250             65500.0
# ...          ...       ...  ...            ...                 ...
# 16995    -124.26     40.58  ...         2.3571            111400.0
# 16996    -124.27     40.69  ...         2.5179             79000.0
# 16997    -124.30     41.84  ...         3.0313            103600.0
# 16998    -124.30     41.80  ...         1.9797             85800.0
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
data.size
# Out:
# 153000

# %%
data.shape
# Out:
# (17000, 9)

# %%
data.ndim
# Out:
# 2

# %%
series_ndim = data["longitude"].ndim
print(series_ndim)
# Out:
# 1

# %%
print(data.shape[0]*data.shape[1])
# Out:
# 153000

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt
y = data["median_income"]
x = data["median_house_value"]
z = data["households"]

# %%
# Histogram
plt.figure(figsize = (10, 10))
plt.hist(x, bins=700)
# Out:
# (array([  4.,   0.,   0.,   1.,   0.,   0.,   0.,   0.,   0.,   0.,   3.,
#           0.,   0.,   0.,   1.,   0.,   1.,   1.,   1.,   1.,   0.,   2.,
#           0.,   0.,   0.,   4.,   0.,   1.,   3.,   0.,   0.,   2.,   3.,
#           1.,   2.,   3.,   4.,   3.,   3.,  12.,   5.,  10.,   6.,   6.,
#           7.,  10.,  15.,  15.,  17.,  18.,  18.,  15.,  19.,  20.,  27.,
#          21.,  40.,  41.,  33.,  22.,  22.,  39.,  37.,  33.,  30.,  25.,
#          35.,  35.,  27.,  27.,  31.,  20.,  37.,  44.,  28.,  75.,  41.,
#          32.,  42.,  45.,  36.,  35.,  54.,  39.,  43.,  31.,  37.,  29.,
#          27.,  30.,  22.,  31.,  32.,  29.,  31.,  48.,  39.,  34.,  40.,
#          37.,  46.,  37.,  50.,  40.,  87.,  47.,  42.,  47.,  60.,  47.,
#          37.,  41.,  64.,  55.,  55.,  63.,  45.,  49.,  57.,  50.,  61.,
#          43.,  69.,  25.,  44.,  24.,  31.,  52.,  43.,  32.,  41.,  44.,
#          26.,  39.,  51.,  40.,  39.,  46.,  43.,  47., 106.,  35.,  61.,
# ...

# %%
# Scatter
plt.figure(figsize=(10, 10))
plt.scatter(x, y)

# %%
# Pie
plt.figure(figsize=(10,10))
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff71eeb5ac8>,
# ...
# ...
#   Text(1.084252572068068, 0.1854625567703074, ''),
#   Text(1.084143248930751, 0.18610055292200497, ''),
#   Text(1.0840649810224656, 0.1865559350992658, ''),
#   Text(1.0839583017922942, 0.18717478456129052, ''),
#   Text(1.083854081645633, 0.1877773407525563, ''),
#   Text(1.0837937468006185, 0.18812526251377598, ''),
#   Text(1.0837377523794114, 0.18844756317772243, ''),
#   Text(1.0836795080573862, 0.18878221265919537, ''),
#   Text(1.083616237222737, 0.18914505128931458, ''),
#   Text(1.0835443969305925, 0.1895561655033114, ''),
#   Text(1.0834635934359207, 0.19001747735122224, ''),
#   Text(1.083365269119766, 0.190577264292091, ''),
#   Text(1.0832783423239558, 0.1910707540464074, ''),
#   Text(1.0832314687193967, 0.19133631431596848, ''),
#   Text(1.083187723907693, 0.19158380614151974, ''),
#   Text(1.083133027524988, 0.19189279476977233, ''),
#   Text(1.083080641667887, 0.1921882505364934, ''),
# ...

# %%
# Polar
plt.figure(figsize = (10, 10))
plt.polar(x, y)

# %%
plt.figure(figsize=(10,10))
plt.stem(x,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %% [markdown]
# **JSON**

# %%
import json as js
import urllib.request

url = "https://api.gdax.com/products/BTC-EUR/ticker"
data = urllib.request.urlopen(url).read().decode()

j_file = js.loads(data)

# %%
j_file
# Out:
# {'ask': '9926.65',
#  'bid': '9926.07',
#  'price': '9926.65',
#  'size': '0.00972376',
#  'time': '2020-08-14T09:49:31.685699Z',
#  'trade_id': 28802807,
#  'volume': '1762.93565426'}

# %%
print('$' + j_file['price'])
# Out:
# $9926.65

# %% [markdown]
# **Image**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

path_img = "/content/drive/My Drive/Projects/Paintings/Rem/Wallpaper_BG.png"

img = cv.imread(path_img)
img1 = cv.imread(path_img, 0)

# %%
scale_percent = 10

#Resizing the image
resize_width = int(img.shape[0] * scale_percent/100)
resize_height = int(img.shape[1] * scale_percent/100)

img_r = cv.resize(img, (resize_height, resize_width))
cv2_imshow(img_r)
# Out:
# <PIL.Image.Image image mode=RGB size=384x216 at 0x7FF6F8446438>

# %%
#Resizing the image
resize_width = int(img1.shape[0] * scale_percent/100)
resize_height = int(img1.shape[1] * scale_percent/100)

img1_r = cv.resize(img1, (resize_height, resize_width))
cv2_imshow(img1_r)
# Out:
# <PIL.Image.Image image mode=L size=384x216 at 0x7FF6F8446320>

# %%
print(img_r.size)
print(img1_r.size)
# Out:
# 248832
# 82944

# %%
# Printing the number of channels
print(img_r.ndim)
print(img1_r.ndim)
# Out:
# 3
# 2

# %%
print("R", img_r.shape[0])
print("G", img_r.shape[1])
print("B", img_r.shape[2])
# Out:
# R 216
# G 384
# B 3

# %%
print("G", img1_r.shape[0])
print("W", img1_r.shape[1])
# Out:
# G 216
# W 384

# %% [markdown]
# **Video**

# %%
vid = cv.VideoCapture("/content/drive/My Drive/Projects/Blender/water-1.mp4")
scale_percent_1 = 10
while(1):
  ret, frame = vid.read()
  
  #Resizing the image
  resize_width_1 = int(frame.shape[0] * scale_percent_1/100)
  resize_height_1 = int(frame.shape[1] * scale_percent_1/100)

  frame_r = cv.resize(frame, (resize_height_1, resize_width_1))
  cv2_imshow(frame_r)

  if cv.waitKey(1) & 0xFF == ord('q') or ret==False :
       cap.release()
       cv.destroyAllWindows()
       break
# Out:
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C18>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918B70>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C18>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918B70>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C88>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C18>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C88>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C18>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C88>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C18>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C88>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C18>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C88>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C50>
# <PIL.Image.Image image mode=RGB size=96x54 at 0x7F2128918C18>
# ...

# %% [markdown]
# **3D Image**

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, c='r', marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# **Audio**

# %%
from IPython.display import Audio
Audio(url="https://file-examples-com.github.io/uploads/2017/11/file_example_MP3_700KB.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="https://file-examples-com.github.io/uploads/2017/11/file_example_MP3_700KB.mp3" type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
