# %% [markdown]
# # Objective: Feature Subset Selection to Improve Software Cost Estimation
#
# ## Dataset
# This is a PROMISE Software Engineering Repository data set made publicly available to encourage repeatable, verifiable, refutable, and/or improvable predictive models of software engineering. The main objective is to estimate the software cost estimation using feature subset selection techniques.
#
# ## Attributes
# 1.	RELY {Nominal,Very_High,High,Low}
# 2.	DATA {High,Low,Nominal,Very_High}
# 3.	CPLX {Very_High,High,Nominal,Extra_High,Low}
# 4.	TIME {Nominal,Very_High,High,Extra_High}
# 5.	STOR {Nominal,Very_High,High,Extra_High}
# 6.	VIRT {Low,Nominal,High}
# 7.	TURN {Nominal,High,Low}
# 8.	ACAP {High,Very_High,Nominal}
# 9.	AEXP {Nominal,Very_High,High}
# 10.	PCAP {Very_High,High,Nominal}
# 11.	VEXP {Low,Nominal,High}
# 12.	LEXP {Nominal,High,Very_Low,Low}
# 13.	MODP {High,Nominal,Very_High,Low}
# 14.	TOOL {Nominal,High,Very_High,Very_Low,Low}
# 15.	SCED {Low,Nominal,High}
# 16.	LOC numeric
#
# ## Target Class
# ACT_EFFORT numeric %17
#
# ### Source: http://promise.site.uottawa.ca/SERepository/datasets/cocomonasa_v1.arff
#
# Tasks:
# 1.	Obtain the software cost estimation dataset
# 2.	Apply pre-processing techniques (if any)
# 3.	Apply feature subset selection techniques such as correlation analysis, forward selection, backward elimination, recursive feature elimination etc. Find best possible subset of features from each method.
# 4.	Divide dataset into training and testing set, respectively.
# 5.	Implement support vector regression (SVR), Linear regression, and Decision tree.
# 6.	Ensemble SVR, Linear regression and Decision tree.
# 7.	Evaluate Coefficient of determination and Root mean square error for all the models including the ensemble one.
# 8.	Conclude the results
#
# Helpful links: https://scikit-learn.org/stable/modules/ensemble.html
# https://www.analyticsvidhya.com/blog/2020/03/support-vector-regression-tutorial-for-machine-learning/
# https://medium.com/pursuitnotes/support-vector-regression-in-6-steps-with-python-c4569acd062d
# https://scikit-learn.org/stable/auto_examples/svm/plot_svm_regression.html

# %% [markdown]
# ## Task 1: Implementation of regression models

# %%
# Load the libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor
from scipy.io import arff
from math import sqrt

# %%
# Load the dataset 
d=arff.loadarff("cocomonasa_v1.arff")
data=pd.DataFrame(d[0])
for col in data.columns:
    if(data[col].dtype==object):
        data[col]=data[col].str.decode('utf-8')
data
# Out:
#          RELY       DATA        CPLX        TIME        STOR     VIRT  \
# 0     Nominal       High   Very_High     Nominal     Nominal      Low
# 1   Very_High       High        High   Very_High   Very_High  Nominal
# 2     Nominal       High        High   Very_High        High      Low
# 3        High        Low        High     Nominal     Nominal      Low
# 4        High        Low        High     Nominal     Nominal      Low
# 5        High        Low        High     Nominal     Nominal      Low
# 6        High        Low        High     Nominal     Nominal      Low
# 7        High        Low        High     Nominal     Nominal      Low
# 8        High        Low        High     Nominal     Nominal      Low
# 9        High        Low        High     Nominal     Nominal      Low
# 10    Nominal    Nominal        High        High     Nominal  Nominal
# 11       High    Nominal        High     Nominal     Nominal  Nominal
# 12    Nominal    Nominal        High     Nominal     Nominal  Nominal
# 13    Nominal    Nominal        High     Nominal     Nominal  Nominal
# 14    Nominal    Nominal        High     Nominal     Nominal  Nominal
# 15       High    Nominal     Nominal        High     Nominal  Nominal
# 16       High    Nominal        High     Nominal     Nominal  Nominal
# 17    Nominal    Nominal     Nominal     Nominal     Nominal  Nominal
# 18    Nominal  Very_High        High   Very_High   Very_High      Low
# 19    Nominal  Very_High        High   Very_High   Very_High      Low
# 20    Nominal  Very_High        High   Very_High   Very_High      Low
# 21    Nominal  Very_High        High   Very_High   Very_High      Low
# 22    Nominal  Very_High        High   Very_High   Very_High      Low
# 23    Nominal  Very_High        High   Very_High   Very_High      Low
# 24    Nominal  Very_High        High   Very_High   Very_High      Low
# 25       High        Low        High     Nominal     Nominal      Low
# 26       High        Low        High     Nominal     Nominal      Low
# 27       High        Low        High     Nominal     Nominal      Low
# 28       High        Low        High     Nominal     Nominal      Low
# 29       High        Low        High     Nominal     Nominal      Low
# 30       High        Low        High     Nominal     Nominal      Low
# 31       High        Low        High     Nominal     Nominal      Low
# 32       High        Low        High     Nominal     Nominal      Low
# 33    Nominal        Low        High     Nominal  Extra_High      Low
# 34    Nominal        Low        High     Nominal     Nominal      Low
# 35    Nominal        Low        High     Nominal     Nominal     High
# 36    Nominal        Low        High     Nominal     Nominal      Low
# 37    Nominal        Low        High     Nominal     Nominal      Low
# 38    Nominal        Low        High     Nominal  Extra_High      Low
# 39    Nominal        Low        High     Nominal     Nominal      Low
# 40    Nominal        Low        High     Nominal     Nominal      Low
# 41    Nominal        Low        High     Nominal     Nominal      Low
# 42    Nominal        Low        High     Nominal     Nominal      Low
# 43    Nominal        Low        High     Nominal     Nominal      Low
# 44       High        Low        High  Extra_High  Extra_High      Low
# 45       High        Low        High     Nominal     Nominal      Low
# 46       High    Nominal        High        High        High      Low
# 47       High    Nominal        High        High        High      Low
# 48       High    Nominal        High        High        High      Low
# 49       High    Nominal   Very_High        High        High      Low
# 50    Nominal    Nominal     Nominal     Nominal     Nominal      Low
# 51    Nominal    Nominal        High     Nominal        High  Nominal
# 52  Very_High    Nominal  Extra_High        High        High      Low
# 53        Low    Nominal     Nominal     Nominal     Nominal      Low
# 54       High       High     Nominal     Nominal     Nominal      Low
# 55       High       High         Low     Nominal     Nominal  Nominal
# 56    Nominal       High         Low     Nominal     Nominal     High
# 57    Nominal       High        High   Very_High     Nominal  Nominal
# 58    Nominal       High        High   Very_High     Nominal  Nominal
# 59    Nominal       High        High   Very_High     Nominal  Nominal
#
#        TURN       ACAP       AEXP       PCAP     VEXP      LEXP       MODP  \
# 0   Nominal       High    Nominal  Very_High      Low   Nominal       High
# 1   Nominal  Very_High  Very_High  Very_High  Nominal      High       High
# 2      High       High    Nominal       High      Low      High       High
# 3       Low    Nominal    Nominal    Nominal  Nominal      High       High
# 4       Low    Nominal    Nominal    Nominal  Nominal      High       High
# 5       Low    Nominal    Nominal    Nominal  Nominal      High       High
# 6       Low    Nominal    Nominal    Nominal  Nominal      High       High
# 7       Low    Nominal    Nominal    Nominal  Nominal      High       High
# 8       Low    Nominal    Nominal    Nominal  Nominal      High       High
# 9       Low    Nominal    Nominal    Nominal  Nominal      High       High
# 10  Nominal    Nominal    Nominal    Nominal  Nominal   Nominal    Nominal
# 11  Nominal    Nominal    Nominal    Nominal  Nominal   Nominal    Nominal
# 12  Nominal    Nominal    Nominal    Nominal  Nominal   Nominal    Nominal
# 13  Nominal    Nominal    Nominal    Nominal  Nominal   Nominal    Nominal
# 14  Nominal    Nominal    Nominal       High  Nominal      High       High
# 15  Nominal    Nominal       High       High  Nominal   Nominal    Nominal
# 16  Nominal    Nominal       High       High  Nominal   Nominal    Nominal
# 17  Nominal    Nominal       High       High  Nominal   Nominal    Nominal
# 18     High  Very_High       High    Nominal      Low      High  Very_High
# 19     High  Very_High       High    Nominal      Low      High  Very_High
# 20     High  Very_High       High    Nominal      Low      High  Very_High
# 21     High  Very_High       High    Nominal      Low      High  Very_High
# 22     High  Very_High       High    Nominal      Low      High  Very_High
# 23     High  Very_High       High    Nominal      Low      High  Very_High
# 24     High  Very_High       High    Nominal      Low      High  Very_High
# 25      Low    Nominal    Nominal    Nominal  Nominal      High       High
# 26      Low    Nominal    Nominal    Nominal  Nominal      High       High
# 27      Low    Nominal    Nominal    Nominal  Nominal      High       High
# 28      Low    Nominal    Nominal    Nominal  Nominal      High       High
# 29      Low    Nominal    Nominal    Nominal  Nominal      High       High
# 30      Low    Nominal    Nominal    Nominal  Nominal      High       High
# 31      Low    Nominal    Nominal    Nominal  Nominal      High       High
# 32      Low    Nominal    Nominal    Nominal  Nominal      High       High
# 33      Low       High  Very_High  Very_High  Nominal      High    Nominal
# 34      Low       High    Nominal    Nominal  Nominal  Very_Low    Nominal
# 35      Low       High       High       High      Low  Very_Low    Nominal
# 36      Low       High  Very_High  Very_High  Nominal      High    Nominal
# 37      Low       High  Very_High       High  Nominal      High    Nominal
# 38      Low       High       High    Nominal  Nominal      High    Nominal
# 39      Low       High       High       High  Nominal      High    Nominal
# 40      Low       High  Very_High       High  Nominal      High    Nominal
# 41      Low       High  Very_High    Nominal  Nominal       Low    Nominal
# 42      Low       High  Very_High  Very_High  Nominal      High    Nominal
# 43      Low       High  Very_High       High  Nominal      High    Nominal
# 44     High       High       High       High  Nominal      High       High
# 45      Low    Nominal    Nominal       High  Nominal   Nominal       High
# 46     High    Nominal       High    Nominal  Nominal   Nominal        Low
# 47     High    Nominal       High    Nominal  Nominal   Nominal        Low
# 48     High    Nominal       High    Nominal  Nominal   Nominal        Low
# 49     High       High    Nominal    Nominal     High      High        Low
# 50  Nominal       High  Very_High  Very_High      Low      High       High
# 51  Nominal       High       High    Nominal  Nominal      High       High
# 52      Low    Nominal       High    Nominal  Nominal   Nominal        Low
# 53      Low       High       High  Very_High  Nominal      High        Low
# 54      Low    Nominal       High       High  Nominal      High    Nominal
# 55     High       High       High    Nominal  Nominal   Nominal       High
# 56  Nominal       High       High    Nominal  Nominal   Nominal       High
# 57     High       High       High       High  Nominal      High        Low
# 58     High       High       High       High  Nominal      High        Low
# 59     High       High       High       High  Nominal      High        Low
#
#          TOOL     SCED    LOC  ACT_EFFORT
# 0     Nominal      Low   70.0       278.0
# 1        High      Low  227.0      1181.0
# 2     Nominal      Low  177.9      1248.0
# 3     Nominal      Low  115.8       480.0
# 4     Nominal      Low   29.5       120.0
# 5     Nominal      Low   19.7        60.0
# 6     Nominal      Low   66.6       300.0
# 7     Nominal      Low    5.5        18.0
# 8     Nominal      Low   10.4        50.0
# 9     Nominal      Low   14.0        60.0
# 10    Nominal  Nominal   16.0       114.0
# 11    Nominal  Nominal    6.5        42.0
# 12    Nominal  Nominal   13.0        60.0
# 13    Nominal  Nominal    8.0        42.0
# 14       High  Nominal   90.0       450.0
# 15    Nominal  Nominal   15.0        90.0
# 16    Nominal  Nominal   38.0       210.0
# 17    Nominal  Nominal   10.0        48.0
# 18  Very_High      Low  161.1       815.0
# 19  Very_High      Low   48.5       239.0
# 20  Very_High      Low   32.6       170.0
# 21  Very_High      Low   12.8        62.0
# 22  Very_High      Low   15.4        70.0
# 23  Very_High      Low   16.3        82.0
# 24  Very_High      Low   35.5       192.0
# 25    Nominal      Low   25.9       117.6
# 26    Nominal      Low   24.6       117.6
# 27    Nominal      Low    7.7        31.2
# 28    Nominal      Low    9.7        25.2
# 29    Nominal      Low    2.2         8.4
# 30    Nominal      Low    3.5        10.8
# 31    Nominal      Low    8.2        36.0
# 32    Nominal      Low   66.6       352.8
# 33    Nominal  Nominal  150.0       324.0
# 34    Nominal  Nominal  100.0       360.0
# 35    Nominal  Nominal  100.0       215.0
# 36    Nominal  Nominal  100.0       360.0
# 37    Nominal  Nominal   15.0        48.0
# 38    Nominal  Nominal   32.5        60.0
# 39    Nominal  Nominal   31.5        60.0
# 40    Nominal  Nominal    6.0        24.0
# 41    Nominal  Nominal   11.3        36.0
# 42    Nominal  Nominal   20.0        72.0
# 43    Nominal  Nominal   20.0        48.0
# 44       High  Nominal    7.5        72.0
# 45   Very_Low  Nominal  302.0      2400.0
# 46  Very_High  Nominal  370.0      3240.0
# 47  Very_High  Nominal  219.0      2120.0
# 48  Very_High  Nominal   50.0       370.0
# 49  Very_High     High  101.0       750.0
# 50    Nominal  Nominal  190.0       420.0
# 51    Nominal     High   47.5       252.0
# 52       High  Nominal   21.0       107.0
# 53        Low     High  423.0      2300.0
# 54    Nominal  Nominal   79.0       400.0
# 55    Nominal  Nominal  284.7       973.0
# 56       High  Nominal  282.1      1368.0
# 57        Low     High   78.0       571.4
# 58        Low     High   11.4        98.8
# 59        Low     High   19.3       155.0

# %%
# Preprocessing
# Encoding categorical variables (if any)
# Feature Scaling
# Filling missing values (if any)
le=LabelEncoder()
minmax=MinMaxScaler()
for col in data.columns:
    if(data[col].dtype==object):
        data[col]=le.fit_transform(data[col])
temp=data.iloc[:,-1]
data=pd.DataFrame(minmax.fit_transform(data.iloc[:,:-1]),columns=data.iloc[:,:-1].columns)
data["ACT_EFFORT"]=temp
data
# Out:
#         RELY      DATA  CPLX      TIME      STOR  VIRT  TURN  ACAP  AEXP  \
# 0   0.666667  0.000000  1.00  0.666667  0.666667   0.5   1.0   0.0   0.5
# 1   1.000000  0.000000  0.25  1.000000  1.000000   1.0   1.0   1.0   1.0
# 2   0.666667  0.000000  0.25  1.000000  0.333333   0.5   0.0   0.0   0.5
# 3   0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 4   0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 5   0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 6   0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 7   0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 8   0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 9   0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 10  0.666667  0.666667  0.25  0.333333  0.666667   1.0   1.0   0.5   0.5
# 11  0.000000  0.666667  0.25  0.666667  0.666667   1.0   1.0   0.5   0.5
# 12  0.666667  0.666667  0.25  0.666667  0.666667   1.0   1.0   0.5   0.5
# 13  0.666667  0.666667  0.25  0.666667  0.666667   1.0   1.0   0.5   0.5
# 14  0.666667  0.666667  0.25  0.666667  0.666667   1.0   1.0   0.5   0.5
# 15  0.000000  0.666667  0.75  0.333333  0.666667   1.0   1.0   0.5   0.0
# 16  0.000000  0.666667  0.25  0.666667  0.666667   1.0   1.0   0.5   0.0
# 17  0.666667  0.666667  0.75  0.666667  0.666667   1.0   1.0   0.5   0.0
# 18  0.666667  1.000000  0.25  1.000000  1.000000   0.5   0.0   1.0   0.0
# 19  0.666667  1.000000  0.25  1.000000  1.000000   0.5   0.0   1.0   0.0
# 20  0.666667  1.000000  0.25  1.000000  1.000000   0.5   0.0   1.0   0.0
# 21  0.666667  1.000000  0.25  1.000000  1.000000   0.5   0.0   1.0   0.0
# 22  0.666667  1.000000  0.25  1.000000  1.000000   0.5   0.0   1.0   0.0
# 23  0.666667  1.000000  0.25  1.000000  1.000000   0.5   0.0   1.0   0.0
# 24  0.666667  1.000000  0.25  1.000000  1.000000   0.5   0.0   1.0   0.0
# 25  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 26  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 27  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 28  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 29  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 30  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 31  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 32  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 33  0.666667  0.333333  0.25  0.666667  0.000000   0.5   0.5   0.0   1.0
# 34  0.666667  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.0   0.5
# 35  0.666667  0.333333  0.25  0.666667  0.666667   0.0   0.5   0.0   0.0
# 36  0.666667  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.0   1.0
# 37  0.666667  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.0   1.0
# 38  0.666667  0.333333  0.25  0.666667  0.000000   0.5   0.5   0.0   0.0
# 39  0.666667  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.0   0.0
# 40  0.666667  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.0   1.0
# 41  0.666667  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.0   1.0
# 42  0.666667  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.0   1.0
# 43  0.666667  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.0   1.0
# 44  0.000000  0.333333  0.25  0.000000  0.000000   0.5   0.0   0.0   0.0
# 45  0.000000  0.333333  0.25  0.666667  0.666667   0.5   0.5   0.5   0.5
# 46  0.000000  0.666667  0.25  0.333333  0.333333   0.5   0.0   0.5   0.0
# 47  0.000000  0.666667  0.25  0.333333  0.333333   0.5   0.0   0.5   0.0
# 48  0.000000  0.666667  0.25  0.333333  0.333333   0.5   0.0   0.5   0.0
# 49  0.000000  0.666667  1.00  0.333333  0.333333   0.5   0.0   0.0   0.5
# 50  0.666667  0.666667  0.75  0.666667  0.666667   0.5   1.0   0.0   1.0
# 51  0.666667  0.666667  0.25  0.666667  0.333333   1.0   1.0   0.0   0.0
# 52  1.000000  0.666667  0.00  0.333333  0.333333   0.5   0.5   0.5   0.0
# 53  0.333333  0.666667  0.75  0.666667  0.666667   0.5   0.5   0.0   0.0
# 54  0.000000  0.000000  0.75  0.666667  0.666667   0.5   0.5   0.5   0.0
# 55  0.000000  0.000000  0.50  0.666667  0.666667   1.0   0.0   0.0   0.0
# 56  0.666667  0.000000  0.50  0.666667  0.666667   0.0   1.0   0.0   0.0
# 57  0.666667  0.000000  0.25  1.000000  0.666667   1.0   0.0   0.0   0.0
# 58  0.666667  0.000000  0.25  1.000000  0.666667   1.0   0.0   0.0   0.0
# 59  0.666667  0.000000  0.25  1.000000  0.666667   1.0   0.0   0.0   0.0
#
#     PCAP  VEXP      LEXP      MODP  TOOL  SCED       LOC  ACT_EFFORT
# 0    1.0   0.5  0.666667  0.000000  0.50   0.5  0.161122       278.0
# 1    1.0   1.0  0.000000  0.000000  0.00   0.5  0.534221      1181.0
# 2    0.0   0.5  0.000000  0.000000  0.50   0.5  0.417538      1248.0
# 3    0.5   1.0  0.000000  0.000000  0.50   0.5  0.269962       480.0
# 4    0.5   1.0  0.000000  0.000000  0.50   0.5  0.064876       120.0
# 5    0.5   1.0  0.000000  0.000000  0.50   0.5  0.041587        60.0
# 6    0.5   1.0  0.000000  0.000000  0.50   0.5  0.153042       300.0
# 7    0.5   1.0  0.000000  0.000000  0.50   0.5  0.007842        18.0
# 8    0.5   1.0  0.000000  0.000000  0.50   0.5  0.019487        50.0
# 9    0.5   1.0  0.000000  0.000000  0.50   0.5  0.028042        60.0
# 10   0.5   1.0  0.666667  0.666667  0.50   1.0  0.032795       114.0
# 11   0.5   1.0  0.666667  0.666667  0.50   1.0  0.010219        42.0
# 12   0.5   1.0  0.666667  0.666667  0.50   1.0  0.025665        60.0
# 13   0.5   1.0  0.666667  0.666667  0.50   1.0  0.013783        42.0
# 14   0.0   1.0  0.000000  0.000000  0.00   1.0  0.208650       450.0
# 15   0.0   1.0  0.666667  0.666667  0.50   1.0  0.030418        90.0
# 16   0.0   1.0  0.666667  0.666667  0.50   1.0  0.085076       210.0
# 17   0.0   1.0  0.666667  0.666667  0.50   1.0  0.018536        48.0
# 18   0.5   0.5  0.000000  1.000000  0.75   0.5  0.377614       815.0
# 19   0.5   0.5  0.000000  1.000000  0.75   0.5  0.110029       239.0
# 20   0.5   0.5  0.000000  1.000000  0.75   0.5  0.072243       170.0
# 21   0.5   0.5  0.000000  1.000000  0.75   0.5  0.025190        62.0
# 22   0.5   0.5  0.000000  1.000000  0.75   0.5  0.031369        70.0
# 23   0.5   0.5  0.000000  1.000000  0.75   0.5  0.033508        82.0
# 24   0.5   0.5  0.000000  1.000000  0.75   0.5  0.079135       192.0
# 25   0.5   1.0  0.000000  0.000000  0.50   0.5  0.056321       117.6
# 26   0.5   1.0  0.000000  0.000000  0.50   0.5  0.053232       117.6
# 27   0.5   1.0  0.000000  0.000000  0.50   0.5  0.013070        31.2
# 28   0.5   1.0  0.000000  0.000000  0.50   0.5  0.017823        25.2
# 29   0.5   1.0  0.000000  0.000000  0.50   0.5  0.000000         8.4
# 30   0.5   1.0  0.000000  0.000000  0.50   0.5  0.003089        10.8
# 31   0.5   1.0  0.000000  0.000000  0.50   0.5  0.014259        36.0
# 32   0.5   1.0  0.000000  0.000000  0.50   0.5  0.153042       352.8
# 33   1.0   1.0  0.000000  0.666667  0.50   1.0  0.351236       324.0
# 34   0.5   1.0  1.000000  0.666667  0.50   1.0  0.232414       360.0
# 35   0.0   0.5  1.000000  0.666667  0.50   1.0  0.232414       215.0
# 36   1.0   1.0  0.000000  0.666667  0.50   1.0  0.232414       360.0
# 37   0.0   1.0  0.000000  0.666667  0.50   1.0  0.030418        48.0
# 38   0.5   1.0  0.000000  0.666667  0.50   1.0  0.072006        60.0
# 39   0.0   1.0  0.000000  0.666667  0.50   1.0  0.069629        60.0
# 40   0.0   1.0  0.000000  0.666667  0.50   1.0  0.009030        24.0
# 41   0.5   1.0  0.333333  0.666667  0.50   1.0  0.021625        36.0
# 42   1.0   1.0  0.000000  0.666667  0.50   1.0  0.042300        72.0
# 43   0.0   1.0  0.000000  0.666667  0.50   1.0  0.042300        48.0
# 44   0.0   1.0  0.000000  0.000000  0.00   1.0  0.012595        72.0
# 45   0.0   1.0  0.666667  0.000000  1.00   1.0  0.712452      2400.0
# 46   0.5   1.0  0.666667  0.333333  0.75   1.0  0.874049      3240.0
# 47   0.5   1.0  0.666667  0.333333  0.75   1.0  0.515209      2120.0
# 48   0.5   1.0  0.666667  0.333333  0.75   1.0  0.113593       370.0
# 49   0.5   0.0  0.000000  0.333333  0.75   0.0  0.234791       750.0
# 50   1.0   0.5  0.000000  0.000000  0.50   1.0  0.446293       420.0
# 51   0.5   1.0  0.000000  0.000000  0.50   0.0  0.107652       252.0
# 52   0.5   1.0  0.666667  0.333333  0.00   1.0  0.044677       107.0
# 53   1.0   1.0  0.000000  0.333333  0.25   0.0  1.000000      2300.0
# 54   0.0   1.0  0.000000  0.666667  0.50   1.0  0.182510       400.0
# 55   0.5   1.0  0.666667  0.000000  0.50   1.0  0.671340       973.0
# 56   0.5   1.0  0.666667  0.000000  0.00   1.0  0.665162      1368.0
# 57   0.0   1.0  0.000000  0.333333  0.25   0.0  0.180133       571.4
# 58   0.0   1.0  0.000000  0.333333  0.25   0.0  0.021863        98.8
# 59   0.0   1.0  0.000000  0.333333  0.25   0.0  0.040637       155.0

# %%
# Apply feature subset selection techniques 
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2,f_classif
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
x_new = SelectKBest(f_classif,k=10).fit_transform(x,y)

# %%
# Divide the dataset to training and testing set
x_train,x_test,y_train,y_test=train_test_split(x_new,np.array(y),random_state=42)

# %%
# Build regression models 
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
lr=LinearRegression()
lr.fit(x_train,y_train)
svr=SVR(kernel="linear")
svr.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
# Evaluate the build model on test dataset
dtr_pred=dtr.predict(x_test)
lr_pred=lr.predict(x_test)
svr_pred=svr.predict(x_test)

# %%
# Evaluate training and testing coefficient of determination and root mean squre error
print("Decision Tree",r2_score(y_test,dtr_pred),sqrt(mean_squared_error(y_test,dtr_pred)))
print("Linear Regression",r2_score(y_test,lr_pred),sqrt(mean_squared_error(y_test,lr_pred)))
print("SVR",r2_score(y_test,svr_pred),sqrt(mean_squared_error(y_test,svr_pred)))
# Out:
# Decision Tree 0.6227524529746309 550.3178838937849
# Linear Regression 0.8578181559726794 337.84888149489274
# SVR -0.30065195900250274 1021.8354465796518

# %% [markdown]
# ##Task 2: Ensemble regression models

# %%
# Ensemble the regression models
ada_dtr=AdaBoostRegressor(base_estimator=dtr)
ada_dtr.fit(x_train,y_train)
ada_dtr_pred=ada_dtr.predict(x_test)
ada_lr=AdaBoostRegressor(base_estimator=lr)
ada_lr.fit(x_train,y_train)
ada_lr_pred=ada_lr.predict(x_test)
ada_svr=AdaBoostRegressor(base_estimator=svr)
ada_svr.fit(x_train,y_train)
ada_svr_pred=ada_svr.predict(x_test)

# %%
# Evaluate Coefficient of determination and Root mean square error 
print("Decision Tree",r2_score(y_test,ada_dtr_pred),sqrt(mean_squared_error(y_test,ada_dtr_pred)))
print("Linear Regression",r2_score(y_test,ada_lr_pred),sqrt(mean_squared_error(y_test,ada_lr_pred)))
print("SVR",r2_score(y_test,ada_svr_pred),sqrt(mean_squared_error(y_test,ada_svr_pred)))
# Out:
# Decision Tree 0.5140361217539982 624.6006169278627
# Linear Regression 0.8970042663784344 287.54778853207915
# SVR -0.2501416252564541 1001.7976812490925
